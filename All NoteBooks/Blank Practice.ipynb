# %%
import numpy as np

# %%
np.random.seed(100)

# %%
from scipy.stats import norm

# %%
from scipy.stats import uniform

# %%
from scipy.stats import binom

# %%
import pandas as pd

# %%
bi=binom.rvs(20,.5,size=365*5)

# %%
Times=pd.date_range(start='2017-6-1',periods=365*5)

# %%
Flippy=norm.rvs(0,25,365*5)

# %%
normal=norm.rvs(0,25,365*5)

# %%
uni=uniform.rvs(0,25,365*5)

# %%
pd.DataFrame({'Date':Times,'Value':bi}).set_index('Date').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.DataFrame({'Date':Times,'Value':normal}).set_index('Date').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.DataFrame({'Date':Times,'Value':uni}).set_index('Date').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norma=pd.DataFrame({'Date':Times,'Value':normal})

# %%
una=pd.DataFrame({'Date':Times,'Value':uni})

# %%
una.set_index('Date').join(norma.iloc[:100,:].set_index('Date'),rsuffix='_norm',lsuffix='_uni',how='right').plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
una.set_index('Date').join(norma.iloc[:100,:].set_index('Date'),rsuffix='_norm',lsuffix='_uni',how='left').plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
una.set_index('Date').join(norma.iloc[:100,:].set_index('Date'),rsuffix='_norm',lsuffix='_uni',how='outer').plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
cascas

# %%
pd.DataFrame({'Date':Times,'Value':uniform.rvs(0,2,365*5)}).assign(Growth=lambda x: x.Value.div(x.Value.shift(periods=1))).plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
uniform.rvs(0,2,365*5)
# Out:
# array([1.53010523, 0.1695192 , 1.9204067 , ..., 1.64440103, 1.85996416,
#        0.1499526 ])
