# %%
#!pip install C:\Users\dmckenzie\Downloads\Fiona-1.8.18-cp39-cp39-win_amd64.whl

# %%
#!pip install C:\Users\dmckenzie\Downloads\Fiona-1.8.18-cp37-cp37m-win_amd64.whl

# %%
#!pip install geopandas

# %%
import geopandas as gp
import pandas as pd
import json
from shapely.geometry import shape

# %%
# read json file
file='C:\\Users\dmckenzie\Downloads\Sample_WE Bench Labeled Project_detached_matthew_conwayN7C2G_detached_matthew_conwayN7C2G_detached_LEVEL 02_Room.json'

# %%
# read json file
with open(file) as json_file:
    json_data = json.load(json_file)

# %%
type(json_data[0])
# Out:
# dict

# %%
json_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'HUDDLE 102 102',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[75.6911199769419, 166.7256544246783, 4.2666015625],
#     [85.37342684420247, 166.7256544246783, 4.2666015625],
#     [85.37342684420247, 155.22450491407938, 4.2666015625],
#     [75.6911199769419, 155.22450491407938, 4.2666015625],
#     [75.6911199769419, 166.7256544246783, 4.2666015625]]]},
#  'properties': {}}

# %%
newdict=json_data[150]

# %%
newdict2={'objects':json_data}

# %%
newdict2['objects']
# Out:
# [{'type': 'Feature',
#   'id': 'HUDDLE 102 102',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[75.6911199769419, 166.7256544246783, 4.2666015625],
#      [85.37342684420247, 166.7256544246783, 4.2666015625],
#      [85.37342684420247, 155.22450491407938, 4.2666015625],
#      [75.6911199769419, 155.22450491407938, 4.2666015625],
#      [75.6911199769419, 166.7256544246783, 4.2666015625]]]},
#   'properties': {}},
#  {'type': 'Feature',
#   'id': 'SMALL CONFERENCE 103 103',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[103.1599741027294, 156.6658714266209, 4.2666015625],
#      [105.44624043972448, 153.27634219176758, 4.2666015625],
#      [99.14363657397905, 153.5757436157944, 4.2666015625],
#      [94.67767439456831, 152.02007948509447, 4.2666015625],
#      [94.68764043081222, 152.00178451585805, 4.2666015625],
#      [94.68274398706365, 151.99911599648556, 4.2666015625],
#      [90.17012695415076, 148.15956273202553, 4.2666015625],
# ...

# %%
with open('newdict.json', 'w') as f:
    json.dump(newdict2, f)

# %%
# read as GeoDataFrame
gdf = gp.GeoDataFrame.from_file(file)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona\_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona\_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: 'C:\Users\dmckenzie\Downloads\Sample_WE Bench Labeled Project_detached_matthew_conwayN7C2G_detached_matthew_conwayN7C2G_detached_LEVEL 02_Room.json' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-100-77eea2e4b237> in <module>
#       1 # read as GeoDataFrame
# ----> 2 gdf = gp.GeoDataFrame.from_file(file)
#
# ~\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\geodataframe.py in from_file(cls, filename, **kwargs)
#     501
#     502         """
# --> 503         return geopandas.io.file._read_file(filename, **kwargs)
#     504
# ...

# %%
#gp.GeoDataFrame(gdf['geometry'].explode()).plot()

# %%
gdf['geometry'][0]

# %%
gdf['geometry'][0]

# %%
gdf['geometry'][0]

# %%
gdf['geometry'][0]

# %%
gdf
# Out:
#                          id                                           geometry
# 0  LARGE CONFERENCE 155 155  POLYGON Z ((134.512 168.919 4.267, 131.670 142...

# %%
gdf.plot()
# Out:
# C:\Users\dmckenzie\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\array.py:917: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 0]),  # minx
# C:\Users\dmckenzie\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\array.py:918: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 1]),  # miny
# C:\Users\dmckenzie\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\array.py:919: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 2]),  # maxx
# C:\Users\dmckenzie\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\array.py:920: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 3]),  # maxy
# C:\Users\dmckenzie\Anaconda3\envs\Three Seven\lib\site-packages\geopandas\plotting.py:410: UserWarning: The GeoSeries you are attempting to plot is composed of empty geometries. Nothing has been displayed.
#   UserWarning,
# <AxesSubplot:>
# ---------------------------------------------------------------------------
# ...
