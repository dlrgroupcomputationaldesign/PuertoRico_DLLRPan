# %%
import pandas as pd

# %%
path='C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/37-20231-00_AR_D6 New K-8 Facility_2020.xlsx'

# %%
'|'.join(['FINISH SCHEDULE - CFCI','FINISH SCHEDULE'])
# Out:
# 'FINISH SCHEDULE - CFCI|FINISH SCHEDULE'

# %%
FinFrame=pd.read_excel(path,sheet_name='FINISH SCHEDULE',header=1)

# %%
path='C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/'+'37-20231-00_AR_D6 New K-8 Facility_2020.xlsx'
xl = pd.ExcelFile(path)
print(pd.Series(xl.sheet_names)[pd.Series(xl.sheet_names).str.upper().str.contains('FINISH SCHEDULE')])
# Out:
# 29               ROOM FINISH SCHEDULE
# 40                    FINISH SCHEDULE
# 41    FINISH SCHEDULE - OWNER PROVIDE
# 49        FINISH SCHEDULE - Guestroom
# 50    FINISH SCHEDULE - Guestroom OWN
# dtype: object

# %%
files=['73-21111-00_Stripe_Core+Shell_2020.xlsx',
       '12-18101-02_WMS_ST_2018_detached.xlsx',
       'STRIPE_SEA_2020.xlsx',
       '37-20231-00_AR_D6 New K-8 Facility_2020.xlsx',
       'STRIPE_SEA_MMoser_2020.xlsx',
       '73-21111-00_Stripe_INT_2020.xlsx',
       '73-21111-00_Stripe_INT-14_2020.xlsx',
'12-18101-02_WMS_MEP_DOOR AND WINDOW_detached.xlsx',
'12-18101-02_WMS_MEP_2018_detached.xlsx',
'12-18101-02_WMS_AR_DOOR AND WINDOW_detached.xlsx',
'12-18101-02_WMS_AR_detached.xlsx',
'12-18101-02_LHS_ST_2018_detached.xlsx',
'12-18101-02_LHS_MEP_2018_detached.xlsx',
'12-18101-02_LHS_AR_2018_detached.xlsx']

# %%
pd.read_excel('C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/'+'73-21111-00_Stripe_Core+Shell_2020.xlsx',sheet_name='FINISH SCHEDULE',header=1)
# Out:
# Empty DataFrame
# Columns: [TAG, DESCRIPTION, MANUFACTURER, PRODUCT, SIZE, COLOR/FINISH, COMMENTS]
# Index: []

# %%
data.columns
# Out:
# Index(['Material number', 'Description', 'Manufacturer', 'Product', 'Size',
#        'Color/finish', 'Notes'],
#       dtype='object')

# %%
BigFrame=pd.DataFrame()
for i in files:
    path='C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/'+i
    xl = pd.ExcelFile(path)
    cfcisum=sum(pd.Series(xl.sheet_names)=='FINISH SCHEDULE - CFCI')
    fssum=sum(pd.Series(xl.sheet_names)=='FINISH SCHEDULE')
    if cfcisum==1:
        data=pd.read_excel(path,sheet_name='FINISH SCHEDULE - CFCI',header=1)
    elif fssum==1:
        data=pd.read_excel(path,sheet_name='FINISH SCHEDULE',header=1)
    else: 
        continue
    data.columns=data.columns.str.lower().str.capitalize()
    BigFrame=BigFrame.append(data)

# %%
BigFrame.\
    assign(Count=1).\
    groupby(['Manufacturer','Product'])['Count'].\
    sum().\
    reset_index().\
    sort_values('Count',ascending=False)
# Out:
#          Manufacturer                                            Product  \
# 133  Sherwin Williams                             Low VOC, Premium Paint
# 126  SHERWIN WILLIAMS                             LOW VOC, PREMIUM PAINT
# 103               MDC                                           TERRALON
# 21     BENJAMIN MOORE                               ULTRA SPEC 500 PAINT
# 12          ARMSTRONG                                 TECTUM WALL PANELS
# ..                ...                                                ...
# 45          DESIGNTEX  ARCHITECTURAL GLASS FILMS - CASPER CLOAKING TE...
# 44            DALTILE                                     PENNY ROUND 1"
# 43           DAL TILE                        KEYNOTES BUILD UP BASE MB5B
# 42           DAL TILE                                           KEYNOTES
# 148          WOW TILE           50% GRADIENT TILE AND 50% GRADIENT DECOR
#
#      Count
# 133     21
# 126     12
# 103     11
# 21       9
# 12       7
# ..     ...
# ...

# %%
#for i in files:
#    path='C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/'+i
#    xl = pd.ExcelFile(path)
#    print('New File')
#    print(pd.Series(xl.sheet_names)[pd.Series(xl.sheet_names).str.upper().str.contains('FINISH SCHEDULE')])

# %%
path='C:/Users/dmckenzie/OneDrive - DLR Group/Desktop/ScheduleExports/37-20231-00_AR_D6 New K-8 Facility_2020.xlsx'
#xl = pd.ExcelFile(path)
#pd.Series(xl.sheet_names)[pd.Series(xl.sheet_names).str.upper().str.contains('FINISH SCHEDULE')]

# %%
FinFrame=pd.read_excel(path,sheet_name='FINISH SCHEDULE - CFCI',header=1)

# %%
FinFrame.head(15)
# Out:
#                       Material Number             Description Manufacturer  \
# 0         03 33 00 Concrete Finishing                     NaN          NaN
# 1                                SC-1     Sealed Concrete BOH          NaN
# 2                                 NaN                     NaN          NaN
# 3              04 40 00 Natural Stone                     NaN          NaN
# 4                                ST-1                   Stone          NaN
# 5                                 NaN                     NaN          NaN
# 6   05 75 00 Decorative Formed Metals                     NaN          NaN
# 7                               MTL-1  Decorative Metal Sheet          NaN
# 8                                 NaN                     NaN          NaN
# 9            06 41 00 Custom Casework                     NaN          NaN
# 10                             HDW-01  Typical Casework Pulls          NaN
# ...

# %%
FinFrame.columns=FinFrame.columns.str.lower().str.capitalize()

# %%
#paintid=FinFrame[FinFrame['Material Number']=='09 90 00 Painting'].index.values[0]
#FinFrame['Row Num']=FinFrame.index.values
#FinFrame['Number']=FinFrame['Material Number'].str[:1].isin(['1','2','3','4','5','6','7','8','9','0'])
#FinFrame['Product'].value_counts()

# %%
FinFrame.tail(25)
# Out:
#                  Material number                  Description  \
# 50                          PT-1                Ceiling Paint
# 51                          PT-2                   Wall Paint
# 52                          PT-3            HM Doors and Trim
# 53                          PT-4               BOH Wall Paint
# 54                        PT-101     Ceiling Paint Guestrooms
# 55                        PT-102        Wall Paint Guestrooms
# 56                        PT-103  HM Doors and Trim Guestroom
# 57                           NaN                          NaN
# 58  10 21 00 Toilet Compartments                          NaN
# 59                          TC-1          Toilet Compartments
# 60                           NaN                          NaN
# 61      10 26 00 Wall Protection                          NaN
# 62                          WP-1        Wall Protection Sheet
# 63                         WP-02                Corner Guards
# ...

# %%
FinFrame.\
    assign(Count=1).\
    groupby(['Manufacturer','Product'])['Count'].\
    sum().\
    reset_index().\
    sort_values('Count',ascending=False)
# Out:
#        Manufacturer                                            Product  Count
# 4  Sherwin Williams                             Low VOC, Premium Paint      7
# 2             InPro                          3/4" Tape on Corner Guard      2
# 0  Crane Composites                                 Glassboard Class A      1
# 1             InPro                1-1/2" Stainless Steel Corner Guard      1
# 3             InPro  4 ft sheet goods with associated top, bottom, ...      1
